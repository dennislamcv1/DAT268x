# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df = pd.read_csv("Ex1.csv",parse_dates=['Date'])

# %%
df
# Out:
#            Place      Item  Price       Date
# 0  Grocery Store  Sandwich    5.0 2017-02-19
# 1         Movie     Ticket    7.5 2017-02-21
# 2            Gas  Gasoline   22.0 2017-02-21
# 3  Grocery Store     Candy    6.0 2017-02-22

# %% [markdown]
# Exercise 2: Create a Chart in Excel Online

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df['Item'],y=df.Price, data=df, ci=None);

# %% [markdown]
# Exercise 3: Modify your data and chart

# %%
plt.figure(figsize=(15,10))
sns.barplot(y=df['Item'],x=df.Price, data=df, ci=None, orient="h");

# %%
df2 = pd.read_csv("Ex2.csv",parse_dates=['Date'])

# %%
df2
# Out:
#               Place        Item  Price       Date
# 0     Grocery Store    Sandwich    5.0 2017-02-19
# 1            Movie       Ticket    7.5 2017-02-21
# 2               Gas    Gasoline   22.0 2017-02-21
# 3     Grocery Store       Candy    6.0 2017-02-22
# 4      Gas Station   Car wash      9.0 2017-02-23
# 5   Grocery Store         Fruit    4.0 2017-02-25
# 6    Pizza Parlor         Pizza   13.0 2017-02-28
# 7           Museum     Tickets     5.0 2017-03-01
# 8    Grocery Store    Sandwich     5.0 2017-03-03
# 9      Gas Station    Car wash    12.0 2017-03-03
# 10  Grocery Store         Fruit    6.0 2017-03-04
# 11    Pizza Parlor       Pizza    11.0 2017-03-05
# 12   Grocery Store       Candy     6.0 2017-03-06

# %%
plt.figure(figsize=(15,10))
sns.barplot(y=df2['Item'],x=df2.Price, data=df, ci=None, orient="h");

# %%
df2
# Out:
#               Place        Item  Price       Date
# 0     Grocery Store    Sandwich    5.0 2017-02-19
# 1            Movie       Ticket    7.5 2017-02-21
# 2               Gas    Gasoline   22.0 2017-02-21
# 3     Grocery Store       Candy    6.0 2017-02-22
# 4      Gas Station   Car wash      9.0 2017-02-23
# 5   Grocery Store         Fruit    4.0 2017-02-25
# 6    Pizza Parlor         Pizza   13.0 2017-02-28
# 7           Museum     Tickets     5.0 2017-03-01
# 8    Grocery Store    Sandwich     5.0 2017-03-03
# 9      Gas Station    Car wash    12.0 2017-03-03
# 10  Grocery Store         Fruit    6.0 2017-03-04
# 11    Pizza Parlor       Pizza    11.0 2017-03-05
# 12   Grocery Store       Candy     6.0 2017-03-06

# %%
df2.sort_values(by=['Price'],inplace=True)

# %%
df2
# Out:
#               Place        Item  Price       Date
# 5   Grocery Store         Fruit    4.0 2017-02-25
# 0     Grocery Store    Sandwich    5.0 2017-02-19
# 7           Museum     Tickets     5.0 2017-03-01
# 8    Grocery Store    Sandwich     5.0 2017-03-03
# 3     Grocery Store       Candy    6.0 2017-02-22
# 10  Grocery Store         Fruit    6.0 2017-03-04
# 12   Grocery Store       Candy     6.0 2017-03-06
# 1            Movie       Ticket    7.5 2017-02-21
# 4      Gas Station   Car wash      9.0 2017-02-23
# 11    Pizza Parlor       Pizza    11.0 2017-03-05
# 9      Gas Station    Car wash    12.0 2017-03-03
# 6    Pizza Parlor         Pizza   13.0 2017-02-28
# 2               Gas    Gasoline   22.0 2017-02-21

# %%
plt.figure(figsize=(15,10))
sns.barplot(y=df2['Item'],x=df2.Price, data=df, ci=None, orient="h");
